# %% [markdown]
# # EMODNET human activities WFS

# %% [markdown]
# ## Install packages

# %%
packages = ['owslib',
            'geopandas',
            'matplotlib.pyplot',
            'contextily',
            'folium'
           ]
for package in packages:
    # !pip install {package} > /dev/null 2>&1
for package in packages:
    exec(f'import {package}')
from owslib.wfs import WebFeatureService
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
from folium.plugins import MarkerCluster

# %% [markdown]
# ## Connect to WFS

# %%
WFS_URL = "https://ows.emodnet-humanactivities.eu/wfs"
wfs = WebFeatureService(url=WFS_URL, version="2.0.0")

# %% [markdown]
# ## List all layers in this WFS

# %%
for i, layer in enumerate(wfs.contents):
    info = wfs.contents[layer]
    print(f"{i} / {len(wfs.contents)}, {layer} — title: {info.title}")
# Out:
# 0 / 134, emodnet:activelicenses — title: Active Licences
# 1 / 134, emodnet:advisorycouncils — title: Advisory Councils
# 2 / 134, emodnet:aquaculture — title: Advisory Councils (Aquaculture)
# 3 / 134, emodnet:baltic — title: Advisory Councils (Baltic)
# 4 / 134, emodnet:blacksea — title: Advisory Councils (Black Sea)
# 5 / 134, emodnet:longdistancefleet — title: Advisory Councils (Long Distance Fleet)
# 6 / 134, emodnet:market — title: Advisory Councils (Market)
# 7 / 134, emodnet:mediterranean — title: Advisory Councils (Mediterranean)
# 8 / 134, emodnet:northsea — title: Advisory Councils (North Sea)
# 9 / 134, emodnet:northwesternwaters — title: Advisory Councils (North Western Waters)
# 10 / 134, emodnet:outermostregions — title: Advisory Councils (Outermost Regions)
# 11 / 134, emodnet:pelagicstocks — title: Advisory Councils (Pelagic Stocks)
# 12 / 134, emodnet:southwesternwaters — title: Advisory Councils (Southwestern Waters)
# 13 / 134, emodnet:aggregateareas — title: Aggregate Extraction Areas
# 14 / 134, emodnet:aggregates — title: Aggregate Extraction Locations
# 15 / 134, emodnet:fishingbeamtrawls — title: Average MW Fishing hours: Beam trawls
# 16 / 134, emodnet:fishingbottomottertrawls — title: Average MW Fishing hours: Bottom otter trawls
# 17 / 134, emodnet:fishingbottomseines — title: Average MW Fishing hours: Bottom seines
# 18 / 134, emodnet:fishingdredges — title: Average MW Fishing hours: Dredges
# 19 / 134, emodnet:fishingpelagic — title: Average MW Fishing hours: Pelagic trawls and seines
# 20 / 134, emodnet:fishingstaticgears — title: Average MW Fishing hours: Static gears
# 21 / 134, emodnet:fishingsubsurface — title: Average Subsurface Swept Area Ratio
# 22 / 134, emodnet:fishingsurface — title: Average Surface Swept Area Ratio
# 23 / 134, emodnet:barcelona — title: Barcelona Convention
# 24 / 134, emodnet:hydrocarbons — title: Boreholes
# 25 / 134, emodnet:bucharest — title: Bucharest Convention
# 26 / 134, emodnet:desalination — title: Desalination Plants
# 27 / 134, emodnet:dischargepoints — title: Discharge Points
# 28 / 134, emodnet:dredgespoil — title: Dredge Spoil Dumping (Points)
# 29 / 134, emodnet:dredgespoilpoly — title: Dredge Spoil Dumping (Polygons)
# 30 / 134, emodnet:dredging — title: Dredging
# 31 / 134, emodnet:munitions — title: Dumped Munitions (Points)
# 32 / 134, emodnet:munitionspoly — title: Dumped Munitions (Polygons)
# 33 / 134, emodnet:emeraldnetwork — title: Emerald Network
# 34 / 134, emodnet:faoareas_old — title: FAO Statistical Areas
# 35 / 134, emodnet:fao_areas — title: FAO Statistical Areas for Fishery Purposes
# 36 / 134, emodnet:finfish — title: Finfish Production
# 37 / 134, emodnet:finfishV1 — title: Finfish Production
# 38 / 134, emodnet:fishsales — title: First Sales of Fish
# 39 / 134, emodnet:fishsalesbyspecies — title: First Sales of Fish by Species
# 40 / 134, emodnet:divisioncatches — title: Fish Catches by FAO Fishery Statistical Areas (Division Area)
# 41 / 134, emodnet:majorcatches — title: Fish Catches by FAO Fishery Statistical Areas (Major Area)
# 42 / 134, emodnet:subareacatches — title: Fish Catches by FAO Fishery Statistical Areas (Sub-area Area)
# 43 / 134, emodnet:subdivisioncatches — title: Fish Catches by FAO Fishery Statistical Areas (Sub-division Area)
# 44 / 134, emodnet:subunitcatches — title: Fish Catches by FAO Fishery Statistical Areas (Sub-unit Area)
# 45 / 134, emodnet:divisioncatchesbygroup — title: Fish Catches by FAO Fishery Statistical Areas and Commodity Group (Division Area)
# 46 / 134, emodnet:majorcatchesbygroup — title: Fish Catches by FAO Fishery Statistical Areas and Commodity Group (Major Area)
# 47 / 134, emodnet:subareacatchesbygroup — title: Fish Catches by FAO Fishery Statistical Areas and Commodity Group (Sub-area Area)
# 48 / 134, emodnet:subdivisioncatchesbygroup — title: Fish Catches by FAO Fishery Statistical Areas and Commodity Group (Sub-division Area)
# 49 / 134, emodnet:subunitcatchesbygroup — title: Fish Catches by FAO Fishery Statistical Areas and Commodity Group (Sub-unit Area)
# 50 / 134, emodnet:divisioncatchesbycountry — title: Fish Catches by FAO Fishery Statistical Areas and Country (Division Area)
# 51 / 134, emodnet:majorcatchesbycountry — title: Fish Catches by FAO Fishery Statistical Areas and Country (Major Area)
# 52 / 134, emodnet:subareacatchesbycountry — title: Fish Catches by FAO Fishery Statistical Areas and Country (Sub-area Area)
# 53 / 134, emodnet:subdivisioncatchesbycountry — title: Fish Catches by FAO Fishery Statistical Areas and Country (Sub-division Area)
# 54 / 134, emodnet:subunitcatchesbycountry — title: Fish Catches by FAO Fishery Statistical Areas and Country (Sub-unit Area)
# 55 / 134, emodnet:divisioneffortbycountry — title: Fishing Effort by FAO Areas/GFCM Subareas and Country (Division Area)
# 56 / 134, emodnet:gfcmsubareaeffortbycountry — title: Fishing Effort by FAO Areas/GFCM Subareas and Country (GFCM Subarea)
# 57 / 134, emodnet:majoreffortbycountry — title: Fishing Effort by FAO Areas/GFCM Subareas and Country (Major Area)
# 58 / 134, emodnet:subareaeffortbycountry — title: Fishing Effort by FAO Areas/GFCM Subareas and Country (Sub-area Area)
# 59 / 134, emodnet:subdivisioneffortbycountry — title: Fishing Effort by FAO Areas/GFCM Subareas and Country (Sub-division Area)
# 60 / 134, emodnet:subuniteffortbycountry — title: Fishing Effort by FAO Areas/GFCM Subareas and Country (Sub-unit Area)
# 61 / 134, emodnet:divisioneffortbyvesseltype — title: Fishing Effort by FAO Areas/GFCM Subareas and Vessel Type (Division Area)
# 62 / 134, emodnet:gfcmsubareaeffortbyvesseltype — title: Fishing Effort by FAO Areas/GFCM Subareas and Vessel Type (GFCM Subarea)
# 63 / 134, emodnet:majoreffortbyvesseltype — title: Fishing Effort by FAO Areas/GFCM Subareas and Vessel Type (Major Area)
# 64 / 134, emodnet:subareaeffortbyvesseltype — title: Fishing Effort by FAO Areas/GFCM Subareas and Vessel Type (Sub-area Area)
# 65 / 134, emodnet:subdivisioneffortbyvesseltype — title: Fishing Effort by FAO Areas/GFCM Subareas and Vessel Type (Sub-division Area)
# 66 / 134, emodnet:subuniteffortbyvesseltype — title: Fishing Effort by FAO Areas/GFCM Subareas and Vessel Type (Sub-unit Area)
# 67 / 134, emodnet:divisioneffort — title: Fishing Effort by FAO Fishery Statistical Areas and GFCM Subareas (Division)
# 68 / 134, emodnet:gfcmsubareaeffort — title: Fishing Effort by FAO Fishery Statistical Areas and GFCM Subareas (GFCM Sub-area)
# 69 / 134, emodnet:majoreffort — title: Fishing Effort by FAO Fishery Statistical Areas and GFCM Subareas (Major)
# 70 / 134, emodnet:subareaeffort — title: Fishing Effort by FAO Fishery Statistical Areas and GFCM Subareas (Sub-area)
# 71 / 134, emodnet:subdivisioneffort — title: Fishing Effort by FAO Fishery Statistical Areas and GFCM Subareas (Sub-division)
# 72 / 134, emodnet:subuniteffort — title: Fishing Effort by FAO Fishery Statistical Areas and GFCM Subareas (Sub-unit)
# 73 / 134, emodnet:fishquotas — title: Fishing Quotas by FMZs
# 74 / 134, emodnet:fishquotas240408 — title: Fishing Quotas by FMZs
# 75 / 134, emodnet:fishquotas240408bylevel — title: Fishing Quotas by FMZs and Level
# 76 / 134, emodnet:fishquotasbylevel — title: Fishing Quotas by FMZs and Level
# 77 / 134, emodnet:fishquotas240408byspecies — title: Fishing Quotas by FMZs and Species
# 78 / 134, emodnet:fishquotasbyspecies — title: Fishing Quotas by FMZs and Species
# 79 / 134, emodnet:freshwater — title: Freshwater Production
# 80 / 134, emodnet:helcom — title: HELCOM Maritime Area
# 81 / 134, emodnet:heritageshipwrecks — title: Heritage Ship Wrecks
# 82 / 134, emodnet:icesareas — title: ICES Statistical Areas
# 83 / 134, emodnet:intconventions — title: International Conventions
# 84 / 134, emodnet:lighthouses — title: Lighthouses
# 85 / 134, emodnet:reportingunits — title: MSFD Reporting Units
# 86 / 134, emodnet:mspspatialplan — title: MSP Spatial Plan Areas
# 87 / 134, emodnet:mspzoningpoly — title: MSP Zoning Areas
# 88 / 134, emodnet:mspzoningline — title: MSP Zoning Lines
# 89 / 134, emodnet:mspzoninglocs — title: MSP Zoning Locations
# 90 / 134, emodnet:macroalgae — title: Macroalgae (seaweeds)
# 91 / 134, emodnet:portgoods — title: Main Ports (Goods Traffic 1997-2024)
# 92 / 134, emodnet:portlocations — title: Main Ports (Locations Only)
# 93 / 134, emodnet:portpassengers — title: Main Ports (Passengers Traffic 1997-2024)
# 94 / 134, emodnet:portvessels — title: Main Ports (Vessles Traffic 1997-2024)
# 95 / 134, emodnet:portvesselsbytonnage — title: Main Ports (Vessles Traffic by Tonnage 1997-2024)
# 96 / 134, emodnet:portvesselsbytype — title: Main Ports (Vessles Traffic by Type 1997-2024)
# 97 / 134, emodnet:microalgae — title: Microalgae
# 98 / 134, emodnet:militaryareas — title: Military Areas (Points)
# 99 / 134, emodnet:militaryareaspoly — title: Military Areas (Polygons)
# 100 / 134, emodnet:cddaareas — title: Nationally Designated Areas
# 101 / 134, emodnet:cddalocations — title: Nationally Designated Areas (Locations)
# 102 / 134, emodnet:natura2000areas — title: Natura 2000
# 103 / 134, emodnet:nuclear — title: Nuclear Power Plants
# 104 / 134, emodnet:ospar — title: OSPAR Maritime Area
# 105 / 134, emodnet:oenergy — title: Ocean Energy - Project Locations
# 106 / 134, emodnet:oenergytests — title: Ocean Energy - Test Sites
# 107 / 134, emodnet:platforms — title: Offshore Installations
# 108 / 134, emodnet:pipelines — title: Pipelines
# 109 / 134, emodnet:pcablesbshcontis — title: Power Cables - DE BSH-CONTIS
# 110 / 134, emodnet:pcablesshom — title: Power Cables - FR SHOM
# 111 / 134, emodnet:pcablesrijks — title: Power Cables - NL Rijkswaterstaat
# 112 / 134, emodnet:pcablesnve — title: Power Cables - NO NVE
# 113 / 134, emodnet:marineprotectedareas — title: Regional Sea Conventions MPAs
# 114 / 134, emodnet:shellfishlics — title: Shellfish Aquaculture Licensed Sites
# 115 / 134, emodnet:shellfish — title: Shellfish Production
# 116 / 134, emodnet:shellfishwfdareas — title: Shellfish Protected Areas under the WFD
# 117 / 134, emodnet:spirulina — title: Spirulina
# 118 / 134, emodnet:bathingwaters — title: State of Bathing Waters
# 119 / 134, emodnet:bshcontiscables — title: Telecommunication Cables - DE BSH-CONTIS
# 120 / 134, emodnet:cicacables — title: Telecommunication Cables - ES CICA
# 121 / 134, emodnet:shomcables — title: Telecommunication Cables - FR SHOM
# 122 / 134, emodnet:sigcables — title: Telecommunication Cables - FR SIGCables
# 123 / 134, emodnet:maltacables — title: Telecommunication Cables - MT IOI-MOC
# 124 / 134, emodnet:rijkscables — title: Telecommunication Cables - NL Rijkswaterstaat
# 125 / 134, emodnet:ukfibrecables — title: Telecommunication Cables - UK OGA
# 126 / 134, emodnet:treatmentplants — title: Treatment Plants
# 127 / 134, emodnet:unescowhl — title: UNESCO World Heritage Convention
# 128 / 134, emodnet:wasteatports — title: Waste at Ports (m3/tonnes)
# 129 / 134, emodnet:windfarms — title: Wind Farms (Points)
# 130 / 134, emodnet:windfarmspoly — title: Wind Farms (Polygons)
# 131 / 134, emodnet:wdpaareas — title: World Database on Protected Areas
# 132 / 134, emodnet:wdpalocations — title: World Database on Protected Areas (Locations)
# 133 / 134, emodnet:wwshipwrecks — title: Worldwide wreck locations (UK Hydrographic Office)

# %% [markdown]
# ## Fetch layer windfarm polygons

# %%
LATER_TO_FETCH = "emodnet:windfarmspoly"

response = wfs.getfeature(
    typename=LATER_TO_FETCH,
    outputFormat="application/json"  # ask for GeoJSON directly
    )
gdf = gpd.read_file(response)

# %% [markdown]
# ### View the data

# %%
print(gdf.head())
# Out:
#                   id         country                                  name  \
# 0  windfarmspoly.241  United Kingdom             Dogger Bank East Met Mast
# 1   windfarmspoly.15  United Kingdom            Scarweather Sands Met Mast
# 2   windfarmspoly.16  United Kingdom  Shell Flats No. 1 (Western) Met Mast
# 3    windfarmspoly.2  United Kingdom                       Islay Demo Zone
# 4   windfarmspoly.17  United Kingdom  Shell Flats No. 2 (Eastern) Met Mast
#
#    n_turbines  power_mw      status updateyear  year     dist_coast  \
# 0         1.0       NaN  Dismantled       None  None  210099.226384
# 1         1.0       NaN  Dismantled       None  None    8166.582792
# 2         1.0       NaN  Production       None  None   15769.864456
# 3        10.0      10.0    Approved       None  None    1122.942248
# 4         1.0       NaN  Production       None  None   10035.848868
#
#    area_sqkm notes  shape_leng  shape_area  \
# 0   0.195959  None    0.019699    0.000028
# 1   0.031385  None    0.007443    0.000004
# 2   0.031393  None    0.007723    0.000004
# 3  27.611537  None    0.291914    0.003946
# 4   0.031393  None    0.007725    0.000004
#
#                                             geometry
# 0  MULTIPOLYGON (((2.70276 55.10165, 2.70297 55.1...
# 1  MULTIPOLYGON (((-3.85893 51.47951, -3.8588 51....
# 2  MULTIPOLYGON (((-3.2959 53.86107, -3.29577 53....
# 3  MULTIPOLYGON (((-6.52572 55.65146, -6.55948 55...
# 4  MULTIPOLYGON (((-3.20373 53.87479, -3.2036 53....

# %% [markdown]
# ## Plot as interactive map

# %%
import folium

# Keep only Polygon / MultiPolygon geometries
gdf_poly = gdf[gdf.geometry.type.isin(["Polygon", "MultiPolygon"])].copy()

# Keep only serializable columns (e.g., object, str, int, float)
serializable_cols = gdf_poly.select_dtypes(include=['int','float','object','bool']).columns
gdf_poly = gdf_poly[serializable_cols.tolist() + ['geometry']]

# Ensure CRS is EPSG:4326
if gdf_poly.crs is None:
    gdf_poly = gdf_poly.set_crs("EPSG:4326")
elif gdf_poly.crs.to_epsg() != 4326:
    gdf_poly = gdf_poly.to_crs(epsg=4326)

# Create folium map centered on the mean bounds
bounds = gdf_poly.total_bounds  # [minx, miny, maxx, maxy]
center = [(bounds[1] + bounds[3])/2, (bounds[0] + bounds[2])/2]
m = folium.Map(location=center, zoom_start=5, tiles="OpenStreetMap")

# Add polygons as GeoJSON
folium.GeoJson(
    gdf_poly.__geo_interface__,
    name="Windfarms",
    tooltip=folium.GeoJsonTooltip(
        fields=[col for col in gdf_poly.columns if col != 'geometry'],
        aliases=[col + ":" for col in gdf_poly.columns if col != 'geometry'],
    ),
    style_function=lambda feature: {
        'fillColor': 'red',
        'color': 'darkred',
        'weight': 1,
        'fillOpacity': 0.5
    }
).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4adf007edc1919c1e3905cc026362a35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4adf007edc1919c1e3905cc026362a35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4adf007edc1919c1e3905cc026362a35 = L.map(
#                 &quot;map_4adf007edc1919c1e3905cc026362a35&quot;,
#                 {
#                     center: [46.601793009999994, 4.07405413],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89982d8d42a2c47018b7de4e17a3d85b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_89982d8d42a2c47018b7de4e17a3d85b.addTo(map_4adf007edc1919c1e3905cc026362a35);
#
#
#         function geo_json_4fae450a2e4933b447e9837069e12a90_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkred&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4fae450a2e4933b447e9837069e12a90_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4fae450a2e4933b447e9837069e12a90 = L.geoJson(null, {
#                 onEachFeature: geo_json_4fae450a2e4933b447e9837069e12a90_onEachFeature,
#
#                 style: geo_json_4fae450a2e4933b447e9837069e12a90_styler,
#             ...{
# }
#         });
#
#         function geo_json_4fae450a2e4933b447e9837069e12a90_add (data) {
#             geo_json_4fae450a2e4933b447e9837069e12a90
#                 .addData(data);
#         }
#             geo_json_4fae450a2e4933b447e9837069e12a90_add({&quot;bbox&quot;: [-16.58967836, 27.73302514, 24.73778662, 65.47056088], &quot;features&quot;: [{&quot;bbox&quot;: [2.69857947, 55.0971645, 2.70640583, 55.10165226], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.70275608, 55.10164731], [2.7029746, 55.10163532], [2.70319161, 55.10161632], [2.70340643, 55.10159037], [2.70361836, 55.10155756], [2.70382675, 55.10151799], [2.70403095, 55.10147177], [2.70423031, 55.10141907], [2.70442419, 55.10136004], [2.704612, 55.10129487], [2.70479314, 55.10122376], [2.70496703, 55.10114694], [2.70513315, 55.10106465], [2.70529095, 55.10097714], [2.70543995, 55.1008847], [2.70557968, 55.10078762], [2.70570969, 55.1006862], [2.70582957, 55.10058076], [2.70593896, 55.10047162], [2.70603751, 55.10035915], [2.70612489, 55.10024368], [2.70620085, 55.10012558], [2.70626515, 55.10000523], [2.70631757, 55.099883], [2.70635795, 55.09975927], [2.70638618, 55.09963445], [2.70640215, 55.09950891], [2.70640583, 55.09938305], [2.70639719, 55.09925728], [2.70637626, 55.09913198], [2.70634312, 55.09900755], [2.70629787, 55.09888438], [2.70624063, 55.09876286], [2.70617161, 55.09864337], [2.70609102, 55.09852629], [2.7059991, 55.09841198], [2.70589615, 55.09830081], [2.70578249, 55.09819313], [2.70565849, 55.09808927], [2.70552452, 55.09798955], [2.70538102, 55.09789431], [2.70522842, 55.09780382], [2.70506723, 55.09771839], [2.70489793, 55.09763827], [2.70472106, 55.09756372], [2.70453719, 55.09749497], [2.70434688, 55.09743225], [2.70415074, 55.09737574], [2.70394939, 55.09732563], [2.70374344, 55.09728207], [2.70353357, 55.0972452], [2.70332042, 55.09721513], [2.70310467, 55.09719197], [2.70288699, 55.09717578], [2.70266807, 55.09716661], [2.7024486, 55.0971645], [2.70222927, 55.09716944], [2.70201076, 55.09718143], [2.70179378, 55.09720043], [2.70157899, 55.09722637], [2.70136707, 55.09725918], [2.7011587, 55.09729875], [2.70095452, 55.09734496], [2.70075519, 55.09739766], [2.70056131, 55.09745668], [2.70037351, 55.09752185], [2.70019238, 55.09759295], [2.70001849, 55.09766977], [2.69985238, 55.09775205], [2.69969458, 55.09783954], [2.69954557, 55.09793198], [2.69940585, 55.09802905], [2.69927583, 55.09813047], [2.69915593, 55.09823591], [2.69904653, 55.09834503], [2.69894797, 55.0984575], [2.69886056, 55.09857297], [2.69878458, 55.09869106], [2.69872027, 55.09881141], [2.69866783, 55.098
