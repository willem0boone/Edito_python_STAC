# %%
import pystac
import xarray as xr
import pandas as pd
from datetime import datetime, date
import pystac_client
from pystac_client import Client
import numpy as np
import copernicusmarine
from copernicusmarine.core_functions import custom_open_zarr

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Open the root catalog
#
# Use pystac-client to connect to a STAC API endpoint (https://catalog.dive.edito.eu/).  We can also connect to a static STAC json catalog, that conforms to STAC and view modelled data from Bio-Oracle.  Also available in Zarr format.

# %%
# STAC API root URL
URL = 'https://api.dive.edito.eu/data/collections'
# URL = 'https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/catalog.json'
# custom headers
headers = []

cat = Client.open(URL, headers=headers)
cat
# Out:
# <Client id=root>

# %%
colls = cat.get_collections()

for coll in colls:
    print(coll.id)
# Out:
# climate_forecast-age_of_sea_ice
# emodnet-aggregate_extraction
# climate_forecast-air_density
# climate_forecast-air_pressure
# climate_forecast-air_pressure_at_mean_sea_level
# climate_forecast-air_temperature
# emodnet-algae_production
# emodnet-aquaculture
# climate_forecast-atmosphere_upward_relative_vorticity
# climate_forecast-barotropic_eastward_sea_water_velocity
# climate_forecast-barotropic_northward_sea_water_velocity
# emodnet-bathymetry_data_quality
# emodnet-bathymetry_source_metadata
# emodnet-beach_litter
# climate_forecast-beaufort_wind_force
# emodnet-cables
# emodnet-calanus_helgolandicus_and_finmarchicus_temporal_change
# climate_forecast-charnock_coefficient_for_surface_roughness_length_for_momentum_in_air
# emodnet-coastal_behaviour
# emodnet-coastlines
# emodnet-composition_of_litter_according_to_material_categories_in_percent_normalized_per_beach_per_year_metal_percent
# emodnet-concentration_of_cadmium
# climate_forecast-concentration_of_colored_dissolved_organic_matter_in_sea_water_expressed_as_equivalent_mass_fraction_of_quinine_sulfate_dihydrate
# emodnet-concentration_of_ddt_dee_and_ddd
# emodnet-concentration_of_hexachlorobenzene
# emodnet-concentration_of_lead
# emodnet-concentration_of_mercury
# emodnet-concentration_of_nickel
# emodnet-concentration_of_pah_anthracene
# emodnet-concentration_of_pah_benzoapyrene
# emodnet-concentration_of_pah_fluoranthene
# emodnet-concentration_of_pah_naphthalene
# emodnet-concentration_of_tributyltin
# emodnet-concentration_of_triphenyltin
# emodnet-contaminants_measurments_counts
# emodnet-cultural_heritage
# emodnet-deepest_values_of_water_body_chlorophyll_a
# emodnet-deepest_values_of_water_body_silicate
# emodnet-desalination
# climate_forecast-dew_point_temperature
# climate_forecast-divergence_of_wind
# climate_forecast-downwelling_photosynthetic_photon_flux_in_sea_water
# emodnet-dredging
# emodnet-earthquakes
# climate_forecast-eastward_sea_ice_velocity
# climate_forecast-eastward_sea_water_velocity
# climate_forecast-eastward_sea_water_velocity_assuming_no_tide
# climate_forecast-eastward_sea_water_velocity_due_to_ekman_drift
# climate_forecast-eastward_wind
# emodnet-elevation
# emodnet-energy
# emodnet-eunis_seabed_habitat_class_2019
# emodnet-fisheries
# emodnet-fisheries_fishing_effort_by_fao_areas_and_gfcm_subareas
# emodnet-fisheries_fishing_intensity
# emodnet-fluid_emissions
# emodnet-folk_16_seabed_substrate_class
# emodnet-folk_5_seabed_substrate_class
# emodnet-folk_7_seabed_substrate_class
# emodnet-folk_sediment_class_amount_of_sampling
# emodnet-folk_sediment_class_boundaries_distinction
# emodnet-folk_sediment_class_remote_sensing_coverage
# climate_forecast-fractional_saturation_of_oxygen_in_sea_water
# climate_forecast-fugacity_of_carbon_dioxide_in_sea_water
# emodnet-geological_event_distribution
# emodnet-geomorphology
# emodnet-geomorphology_lines
# climate_forecast-geopotential_height
# climate_forecast-geostrophic_eastward_sea_water_velocity
# climate_forecast-geostrophic_northward_sea_water_velocity
# climate_forecast-global_average_steric_sea_level_change
# emodnet-individual_habitat_maps_from_surveys_essential_fish_habitats
# emodnet-kinetic_energy_at_the_seabed_due_to_currents
# climate_forecast-latitude
# climate_forecast-longitude
# climate_forecast-lwe_precipitation_rate
# climate_forecast-magnitude_of_surface_downward_stress
# emodnet-main_ports
# emodnet-marine_aggregate_extraction_areas_site_type
# emodnet-marine_aggregate_extraction_areas_status
# emodnet-marine_aggregates
# emodnet-marine_aggregates_deposit_type
# emodnet-marine_aggregates_economic_feasibility
# emodnet-marine_critical_minerals
# emodnet-marine_hydrocarbon_and_hydrates
# emodnet-marine_hydrocarbon_sub_deposits
# emodnet-marine_non_critical_minerals
# emodnet-marine_strategy_framework_directive_benthic_broad_habitat_type
# emodnet-maritime_spatial_planning
# climate_forecast-mass_concentration_of_chlorophyll_a_in_sea_water
# climate_forecast-mass_concentration_of_chlorophyll_in_sea_water
# climate_forecast-mass_concentration_of_diatoms_expressed_as_chlorophyll_in_sea_water
# climate_forecast-mass_concentration_of_microphytoplankton_expressed_as_chlorophyll_in_sea_water
# climate_forecast-mass_concentration_of_nanophytoplankton_expressed_as_chlorophyll_in_sea_water
# climate_forecast-mass_concentration_of_picophytoplankton_expressed_as_chlorophyll_in_sea_water
# climate_forecast-mass_concentration_of_suspended_matter_in_sea_water
# emodnet-micro_litter
# emodnet-military_areas
# climate_forecast-mole_concentration_of_ammonium_in_sea_water
# climate_forecast-mole_concentration_of_diatoms_expressed_as_carbon_in_sea_water
# climate_forecast-mole_concentration_of_dissolved_inorganic_carbon_in_sea_water
# climate_forecast-mole_concentration_of_dissolved_iron_in_sea_water
# climate_forecast-mole_concentration_of_dissolved_molecular_oxygen_in_sea_water
# climate_forecast-mole_concentration_of_hydrogen_sulfide_in_sea_water
# climate_forecast-mole_concentration_of_nitrate_and_nitrite_in_sea_water
# climate_forecast-mole_concentration_of_nitrate_in_sea_water
# climate_forecast-mole_concentration_of_nitrite_in_sea_water
# climate_forecast-mole_concentration_of_phosphate_in_sea_water
# climate_forecast-mole_concentration_of_phytoplankton_expressed_as_carbon_in_sea_water
# climate_forecast-mole_concentration_of_picophytoplankton_expressed_as_carbon_in_sea_water
# climate_forecast-mole_concentration_of_silicate_in_sea_water
# climate_forecast-mole_concentration_of_zooplankton_expressed_as_carbon_in_sea_water
# climate_forecast-moles_of_dissolved_inorganic_carbon_per_unit_mass_in_sea_water
# climate_forecast-moles_of_nitrate_per_unit_mass_in_sea_water
# climate_forecast-moles_of_nitrite_per_unit_mass_in_sea_water
# climate_forecast-moles_of_oxygen_per_unit_mass_in_sea_water
# climate_forecast-moles_of_phosphate_per_unit_mass_in_sea_water
# climate_forecast-moles_of_silicate_per_unit_mass_in_sea_water
# emodnet-monitored_matrices
# climate_forecast-net_downward_shortwave_flux_at_sea_water_surface
# climate_forecast-net_primary_production_of_biomass_expressed_as_carbon_per_unit_volume_in_sea_water
# climate_forecast-northward_sea_ice_velocity
# climate_forecast-northward_sea_water_velocity
# climate_forecast-northward_sea_water_velocity_assuming_no_tide
# climate_forecast-northward_sea_water_velocity_due_to_ekman_drift
# climate_forecast-northward_wind
# climate_forecast-number_of_icebergs_per_unit_area
# climate_forecast-number_of_observations
# emodnet-occurrence_data
# climate_forecast-ocean_barotropic_streamfunction
# emodnet-ocean_energy_projects_start_year
# climate_forecast-ocean_meridional_overturning_streamfunction
# climate_forecast-ocean_mixed_layer_thickness
# climate_forecast-ocean_mixed_layer_thickness_defined_by_sigma_theta
# climate_forecast-ocean_volume_transport_across_line
# emodnet-oil_and_gas
# emodnet-other_forms_of_area_management
# emodnet-physiographic_features
# emodnet-phytoplankton_biomass_and_diversity
# emodnet-pipelines
# climate_forecast-platform_zenith_angle
# emodnet-pre_quaternary_faults
# emodnet-pre_quaternary_geology_age
# emodnet-pre_quaternary_lithology
# climate_forecast-precipitation_flux
# emodnet-protected_areas
# climate_forecast-quality_flag
# emodnet-quaternary_geology_age
# emodnet-quaternary_geology_lithology
# emodnet-quaternary_tectonics
# climate_forecast-relative_humidity
# emodnet-river_outflow
# emodnet-route_density_annual_totals
# emodnet-route_density_monthly_totals
# emodnet-route_density_seasonal_totals
# climate_forecast-sea_floor_depth_below_mean_sea_level
# emodnet-sea_floor_litter
# climate_forecast-sea_ice_albedo
# climate_forecast-sea_ice_area_fraction
# climate_forecast-sea_ice_classification
# climate_forecast-sea_ice_extent
# climate_forecast-sea_ice_speed
# climate_forecast-sea_ice_surface_temperature
# climate_forecast-sea_ice_thickness
# climate_forecast-sea_ice_transport_across_line
# climate_forecast-sea_ice_volume
# climate_forecast-sea_ice_x_displacement
# climate_forecast-sea_ice_x_velocity
# climate_forecast-sea_ice_y_displacement
# climate_forecast-sea_ice_y_velocity
# climate_forecast-sea_surface_density
# climate_forecast-sea_surface_foundation_temperature
# climate_forecast-sea_surface_height_above_geoid
# climate_forecast-sea_surface_height_above_mean_sea_level
# climate_forecast-sea_surface_height_amplitude_due_to_geocentric_ocean_tide
# climate_forecast-sea_surface_height_correction_due_to_air_pressure_at_low_frequency
# climate_forecast-sea_surface_primary_swell_wave_from_direction
# climate_forecast-sea_surface_primary_swell_wave_from_direction_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_primary_swell_wave_mean_period
# climate_forecast-sea_surface_primary_swell_wave_period_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_primary_swell_wave_significant_height
# climate_forecast-sea_surface_salinity
# climate_forecast-sea_surface_secondary_swell_wave_from_direction
# climate_forecast-sea_surface_secondary_swell_wave_from_direction_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_secondary_swell_wave_mean_period
# climate_forecast-sea_surface_secondary_swell_wave_period_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_secondary_swell_wave_significant_height
# climate_forecast-sea_surface_subskin_temperature
# climate_forecast-sea_surface_temperature
# climate_forecast-sea_surface_tertiary_swell_wave_from_direction_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_tertiary_swell_wave_period_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_tertiary_swell_wave_significant_height
# climate_forecast-sea_surface_wave_directional_spread_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_wave_energy_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_wave_from_direction
# climate_forecast-sea_surface_wave_from_direction_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_wave_maximum_crest_height
# climate_forecast-sea_surface_wave_maximum_height
# climate_forecast-sea_surface_wave_maximum_period
# climate_forecast-sea_surface_wave_maximum_steepness
# climate_forecast-sea_surface_wave_mean_height
# climate_forecast-sea_surface_wave_mean_height_of_highest_tenth
# climate_forecast-sea_surface_wave_mean_period
# climate_forecast-sea_surface_wave_mean_period_from_variance_spectral_density_inverse_frequency_moment
# climate_forecast-sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment
# climate_forecast-sea_surface_wave_mean_period_of_highest_tenth
# climate_forecast-sea_surface_wave_period_at_variance_spectral_density_maximum
# climate_forecast-sea_surface_wave_period_of_highest_wave
# climate_forecast-sea_surface_wave_significant_height
# climate_forecast-sea_surface_wave_significant_period
# climate_forecast-sea_surface_wave_stokes_drift_x_velocity
# climate_forecast-sea_surface_wave_stokes_drift_y_velocity
# climate_forecast-sea_surface_wind_wave_from_direction
# climate_forecast-sea_surface_wind_wave_mean_period
# climate_forecast-sea_surface_wind_wave_significant_height
# climate_forecast-sea_water_alkalinity_expressed_as_mole_equivalent
# climate_forecast-sea_water_conservative_temperature
# climate_forecast-sea_water_electrical_conductivity
# climate_forecast-sea_water_ph_reported_on_total_scale
# climate_forecast-sea_water_potential_temperature
# climate_forecast-sea_water_potential_temperature_at_sea_floor
# climate_forecast-sea_water_potential_temperature_expressed_as_heat_content
# climate_forecast-sea_water_practical_salinity
# climate_forecast-sea_water_pressure_at_sea_floor
# climate_forecast-sea_water_salinity
# climate_forecast-sea_water_salinity_at_sea_floor
# climate_forecast-sea_water_sigma_theta
# climate_forecast-sea_water_speed
# climate_forecast-sea_water_temperature
# climate_forecast-sea_water_turbidity
# climate_forecast-sea_water_velocity_to_direction
# climate_forecast-sea_water_volume
# climate_forecast-sea_water_x_velocity
# climate_forecast-sea_water_y_velocity
# emodnet-seabed_energy
# emodnet-seabed_substrate
# climate_forecast-secchi_depth_of_sea_water
# emodnet-shipwreck_maximum_depth
# emodnet-shipwreck_object_description
# emodnet-shipwreck_object_type
# climate_forecast-sinking_mole_flux_of_particulate_organic_matter_expressed_as_carbon_in_sea_water
# climate_forecast-solar_zenith_angle
# climate_forecast-specific_kinetic_energy_of_sea_water
# climate_forecast-specific_turbulent_kinetic_energy_of_sea_water
# climate_forecast-speed_of_sound_in_sea_water
# climate_forecast-status_flag
# emodnet-submarine_landslide_activity_type
# emodnet-submarine_landslides
# emodnet-submarine_volcanoes
# emodnet-submerged_landscapes
# climate_forecast-surface_downward_eastward_stress
# climate_forecast-surface_downward_eastward_stress_due_to_ocean_viscous_dissipation
# climate_forecast-surface_downward_heat_flux_in_sea_water
# climate_forecast-surface_downward_latent_heat_flux
# climate_forecast-surface_downward_mass_flux_of_carbon_dioxide_expressed_as_carbon
# climate_forecast-surface_downward_northward_stress
# climate_forecast-surface_downward_northward_stress_due_to_ocean_viscous_dissipation
# climate_forecast-surface_downward_sensible_heat_flux
# climate_forecast-surface_downward_x_stress
# climate_forecast-surface_downward_y_stress
# climate_forecast-surface_downwelling_longwave_flux_in_air
# climate_forecast-surface_downwelling_photosynthetic_photon_flux_in_air
# climate_forecast-surface_downwelling_shortwave_flux_in_air
# climate_forecast-surface_geostrophic_eastward_sea_water_velocity
# climate_forecast-surface_geostrophic_eastward_sea_water_velocity_assuming_mean_sea_level_for_geoid
# climate_forecast-surface_geostrophic_northward_sea_water_velocity
# climate_forecast-surface_geostrophic_northward_sea_water_velocity_assuming_mean_sea_level_for_geoid
# climate_forecast-surface_net_downward_longwave_flux
# climate_forecast-surface_partial_pressure_of_carbon_dioxide_in_sea_water
# climate_forecast-surface_ratio_of_upwelling_radiance_emerging_from_sea_water_to_downwelling_radiative_flux_in_air
# climate_forecast-surface_roughness_length
# climate_forecast-surface_sea_water_x_velocity
# climate_forecast-surface_sea_water_y_velocity
# climate_forecast-surface_snow_thickness
# climate_forecast-surface_temperature
# climate_forecast-surface_water_evaporation_flux
# climate_forecast-tendency_of_air_pressure
# climate_forecast-tendency_of_sea_surface_height_above_mean_sea_level
# climate_forecast-thermosteric_change_in_mean_sea_level
# climate_forecast-time
# emodnet-tsunamis
# emodnet-underwater_noise
# climate_forecast-upward_sea_water_velocity
# emodnet-vessel_density_annual_averages
# emodnet-vessel_density_monthly_totals
# emodnet-view_of_elaborated_products
# emodnet-volcanic_activity_type
# climate_forecast-volume_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water
# climate_forecast-volume_beam_attenuation_coefficient_of_radiative_flux_in_sea_water
# climate_forecast-volume_fraction_of_oxygen_in_sea_water
# emodnet-waste_disposal
# emodnet-water_body_ammonium
# emodnet-water_body_chlorophyll_a
# emodnet-water_body_chlorophyll_a_deepest
# emodnet-water_body_chlorophyll_a_masked_using_relative_error_threshold_0.5
# emodnet-water_body_dissolved_inorganic_nitrogen
# emodnet-water_body_dissolved_inorganic_nitrogen_masked_using_relative_error_threshold_0.5
# emodnet-water_body_dissolved_oxygen_concentration
# emodnet-water_body_dissolved_oxygen_concentration_masked_using_relative_error_threshold_0.5
# emodnet-water_body_phosphate
# emodnet-water_body_phosphate_masked_using_relative_error_threshold_0.5
# emodnet-water_body_silicate
# emodnet-water_body_silicate_masked_using_relative_error_threshold_0.5
# climate_forecast-water_flux_into_sea_water_from_rivers
# climate_forecast-water_flux_out_of_sea_ice_and_sea_water
# climate_forecast-water_surface_height_above_reference_datum
# climate_forecast-water_volume_transport_into_sea_water_from_rivers
# emodnet-wave_exposure_index_at_the_sea_surface
# climate_forecast-wet_bulb_temperature
# emodnet-wind_farm_area_sq_km
# emodnet-wind_farm_power_mw
# emodnet-wind_farm_year
# climate_forecast-wind_from_direction
# climate_forecast-wind_gust_from_direction
# climate_forecast-wind_speed
# climate_forecast-wind_speed_of_gust
# climate_forecast-wind_to_direction
# emodnet-zooplankton_biomass_and_diversity

# %% [markdown]
# ### Browse the Catalog
# Navigate through the root catalog to find sub-catalogs and collections of interest

# %%
collections = cat.get_collections()
for collection in collections:
    if 'chlorophyll' in collection.id:
        print(collection.id)
        for item in collection.get_all_items():
            print(item.id)
            print(item.assets)
            break
# Out:
# emodnet-deepest_values_of_water_body_chlorophyll_a
# e9d70b7e-80da-5db2-9053-5e3540ad0c60
# {'xml': <Asset href=https://emodnet.ec.europa.eu/geonetwork/srv/api/records/a3461fb1-d209-440e-a49f-7acff7731395/formatters/xml>, 'csw': <Asset href=https://emodnet.ec.europa.eu/geonetwork/emodnet/eng/csw?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=a3461fb1-d209-440e-a49f-7acff7731395>, 'html': <Asset href=http://opendap.oceanbrowser.net/thredds/dodsC/data/emodnet-domains/By_sea_regions/Northeast_Atlantic_Ocean/Water_body_chlorophyll-a.4Danl.nc.html>, 'netcdf': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_native/emodnet_chemistry/water_body_chlorophyll_a/water_body_chlorophyll_a_masked_using_relative_error_threshold_0.3_northeast_atlantic_ocean/Water_body_chlorophyll-a.4Danl.nc>, 'zarr': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_arco/emodnet_chemistry/water_body_chlorophyll_a/deepest_values_of_water_body_chlorophyll_a_northeast_atlantic_ocean/Water_body_chlorophyll-a.4Danl.zarr>, 'zarr-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_arco/emodnet_chemistry/water_body_chlorophyll_a/deepest_values_of_water_body_chlorophyll_a_northeast_atlantic_ocean/Water_body_chlorophyll-a.4Danl.zarr>}
# climate_forecast-mass_concentration_of_chlorophyll_a_in_sea_water
# 58a30a8c-f2dd-585f-87b4-61aa1eefc70c
# {'arco-time-series': <Asset href=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-001/arco/BALTICSEA_ANALYSISFORECAST_BGC_003_007/cmems_mod_bal_bgc_anfc_7-10days_P1D-m_202411/geoChunked.zarr>, 'wmts': <Asset href=https://wmts.marine.copernicus.eu/teroWmts/BALTICSEA_ANALYSISFORECAST_BGC_003_007/cmems_mod_bal_bgc_anfc_7-10days_P1D-m_202411?layer=BALTICSEA_ANALYSISFORECAST_BGC_003_007/cmems_mod_bal_bgc_anfc_7-10days_P1D-m_202411/chl>, 'arco-time-series-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-001/arco/BALTICSEA_ANALYSISFORECAST_BGC_003_007/cmems_mod_bal_bgc_anfc_7-10days_P1D-m_202411/geoChunked.zarr>}
# climate_forecast-mass_concentration_of_chlorophyll_in_sea_water
# 59afc1f2-24a0-5087-8609-a2374dc6ae08
# {'arco-time-series': <Asset href=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-060/arco/INSITU_NWS_PHYBGCWAV_DISCRETE_MYNRT_013_036/cmems_obs-ins_nws_phybgcwav_mynrt_na_irr_202311--ext--latest/geoChunked>}
# climate_forecast-mass_concentration_of_diatoms_expressed_as_chlorophyll_in_sea_water
# a442e5d2-6b25-586f-ad5a-af1506ab1b2d
# {'arco-time-series': <Asset href=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>, 'wmts': <Asset href=https://wmts.marine.copernicus.eu/teroWmts/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411?layer=OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/DIATO>, 'arco-time-series-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>}
# climate_forecast-mass_concentration_of_microphytoplankton_expressed_as_chlorophyll_in_sea_water
# 3259cc01-3c13-5a4f-b1a9-e88e5bb9dd17
# {'arco-time-series': <Asset href=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>, 'wmts': <Asset href=https://wmts.marine.copernicus.eu/teroWmts/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411?layer=OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/MICRO>, 'arco-time-series-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>}
# climate_forecast-mass_concentration_of_nanophytoplankton_expressed_as_chlorophyll_in_sea_water
# b2e43013-0ad5-53fd-929f-30da868d4c9b
# {'arco-time-series': <Asset href=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>, 'wmts': <Asset href=https://wmts.marine.copernicus.eu/teroWmts/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411?layer=OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/NANO>, 'arco-time-series-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>}
# climate_forecast-mass_concentration_of_picophytoplankton_expressed_as_chlorophyll_in_sea_water
# 2cf926c3-ae2d-5278-956d-556696080286
# {'arco-time-series': <Asset href=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>, 'wmts': <Asset href=https://wmts.marine.copernicus.eu/teroWmts/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411?layer=OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/PICO>, 'arco-time-series-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/mdl-arco-geo-042/arco/OCEANCOLOUR_BAL_BGC_L3_NRT_009_131/cmems_obs-oc_bal_bgc-plankton_nrt_l3-olci-300m_P1D_202411/geoChunked.zarr>}
# emodnet-water_body_chlorophyll_a
# 2d7f2f95-c558-5aa2-b338-c48cfec85c54
# {'xml': <Asset href=https://emodnet.ec.europa.eu/geonetwork/srv/api/records/eea90fe0-0753-4d90-8c03-45d47627c2e4/formatters/xml>, 'csw': <Asset href=https://emodnet.ec.europa.eu/geonetwork/emodnet/eng/csw?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=eea90fe0-0753-4d90-8c03-45d47627c2e4>, 'png': <Asset href=https://sextant.ifremer.fr/geonetwork/srv/api/records/eea90fe0-0753-4d90-8c03-45d47627c2e4/attachments/Water%20body%20chlorophyll-a_01_002.png>, 'html': <Asset href=http://opendap.oceanbrowser.net/thredds/dodsC/data/emodnet-domains/Coastal_areas/Baltic_Sea_-_Gulf_of_Riga/Water_body_chlorophyll-a.nc.html>, 'netcdf': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_native/emodnet_chemistry/water_body_chlorophyll_a/deepest_values_of_water_body_chlorophyll_a_baltic_sea_gulf_of_riga/Water_body_chlorophyll-a.nc>}
# emodnet-water_body_chlorophyll_a_deepest
# 51adff2b-06c0-52c8-9b79-dcbfa9f98da3
# {'xml': <Asset href=http://ec.oceanbrowser.net/emodnet/Python/web/wms?service=WMS&request=GetMap&version=1.3.0&crs=CRS%3A84&bbox=-20.0%2C47.0%2C25.0%2C63.0&decorated=true&format=image%2Fpng&layers=By%20sea%20regions%2FNorth%20Sea%2Fready_for_divadoxml%2FWater_body_chlorophyll-a.4Danl.nc%2AWater%20body%20chlorophyll-a_L1&styles=vmin%3A0.0%2Bvmax%3A45.13986709594726&transparent=true&height=500&width=800&basemap=shadedrelief&time=summer%202013>, 'csw': <Asset href=https://emodnet.ec.europa.eu/geonetwork/emodnet/eng/csw?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=de582896-dd8c-413b-b9a7-1774de2e6344>, 'html': <Asset href=http://opendap.oceanbrowser.net/thredds/dodsC/data/emodnet-domains/By_sea_regions/North_Sea/Water_body_chlorophyll-a.4Danl.nc.html>, 'netcdf': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_native/emodnet_chemistry/water_body_chlorophyll_a/relative_error_of_water_body_chlorophyll_a_north_sea/Water_body_chlorophyll-a.4Danl.nc>, 'zarr': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_arco/emodnet_chemistry/water_body_chlorophyll_a/deepest_values_of_water_body_chlorophyll_a_north_sea/Water_body_chlorophyll-a.4Danl.zarr>, 'zarr-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_arco/emodnet_chemistry/water_body_chlorophyll_a/deepest_values_of_water_body_chlorophyll_a_north_sea/Water_body_chlorophyll-a.4Danl.zarr>}
# emodnet-water_body_chlorophyll_a_masked_using_relative_error_threshold_0.5
# 6bee75eb-b3a1-53e6-a7d1-8ee3550830a0
# {'xml': <Asset href=https://emodnet.ec.europa.eu/geonetwork/srv/api/records/d4fa14db-81f5-4127-9425-75edc43462c3/formatters/xml>, 'csw': <Asset href=https://emodnet.ec.europa.eu/geonetwork/emodnet/eng/csw?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=d4fa14db-81f5-4127-9425-75edc43462c3>, 'png': <Asset href=https://sextant.ifremer.fr/geonetwork/srv/api/records/d4fa14db-81f5-4127-9425-75edc43462c3/attachments/Water_body_chlorophyll-a_L2_in_Water_body_chlorophyll-a.4Danl.png>, 'html': <Asset href=http://opendap.oceanbrowser.net/thredds/dodsC/data/emodnet-domains/By_sea_regions/Black_Sea/Water_body_chlorophyll-a.4Danl.nc.html>, 'netcdf': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_native/emodnet_chemistry/water_body_chlorophyll_a/relative_error_of_water_body_chlorophyll_a_black_sea/Water_body_chlorophyll-a.4Danl.nc>, 'zarr': <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_arco/emodnet_chemistry/water_body_chlorophyll_a/water_body_chlorophyll_a_masked_using_relative_error_threshold_0.5_black_sea/Water_body_chlorophyll-a.4Danl.zarr>, 'zarr-datalab-data-explorer': <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_arco/emodnet_chemistry/water_body_chlorophyll_a/water_body_chlorophyll_a_masked_using_relative_error_threshold_0.5_black_sea/Water_body_chlorophyll-a.4Danl.zarr>}

# %% [markdown]
# ### Search for a Collection
# Identify a collection based on your variables (e.g., temperature, salinity). You can filter by collection metadata like keywords or spatial/temporal bounds.

# %%
all_items = []
collection_selection = ['oxygen', 'habitat', 'elevation', 'temperature']
for collection in cat.get_collections():
    if 'oxygen' in collection.id or 'habitat' in collection.id or 'temperature' in collection.id:
        collection_items = collection.get_all_items()
        try:
            for item in collection_items:
                # Append item information to the list
                all_items.append({  'Collection ID': collection.id, 
                                    'Item ID': item.id,
                                    'Item bounds': item.geometry, 
                                    'item_starttime': item.properties['start_datetime'],
                                    'item_endtime': item.properties['end_datetime'], 
                                    'Assets': item.assets})
        except Exception as e:
            print(e)
            print(f'Error with {collection.id}')
            continue
oxygen_habitat_temperature_items_df = pd.DataFrame(all_items)
oxygen_habitat_temperature_items_df.head()
# Out:
#                       Collection ID                               Item ID  \
# 0  climate_forecast-air_temperature  8ebf3d6d-1a6f-58f8-beb3-e6ff6eae3c90
# 1  climate_forecast-air_temperature  33857744-4f8c-5eb2-acc7-3cf15e6026b7
# 2  climate_forecast-air_temperature  139f5e61-86d9-562a-b24d-d940bb0b25c7
# 3  climate_forecast-air_temperature  962e103b-9fec-5b95-ab3a-9f8633c03e38
# 4  climate_forecast-air_temperature  99b5c8e6-696f-5512-9f59-2f6e53caf374
#
#                                          Item bounds  \
# 0  {'type': 'Polygon', 'coordinates': [[[-52.9000...
# 1  {'type': 'Polygon', 'coordinates': [[[-52.9000...
# 2  {'type': 'Polygon', 'coordinates': [[[-14.4, -...
# 3  {'type': 'Polygon', 'coordinates': [[[-14.4, -...
# 4  {'type': 'Polygon', 'coordinates': [[[-171, -3...
#
#                 item_starttime                 item_endtime  \
# 0  2024-12-11T00:00:00.000000Z  2025-01-10T10:10:00.000000Z
# 1  2024-12-11T00:00:00.000000Z  2025-01-10T10:10:00.000000Z
# 2  2024-12-11T00:00:00.000000Z  2025-01-10T09:19:00.000000Z
# 3  2024-12-11T00:00:00.000000Z  2025-01-10T09:19:00.000000Z
# 4  2024-12-11T00:00:00.000000Z  2025-01-10T10:13:00.000000Z
#
#                                               Assets
# 0  {'arco-time-series': <Asset href=https://s3.wa...
# 1  {'arco-geo-series': <Asset href=https://s3.waw...
# 2  {'arco-time-series': <Asset href=https://s3.wa...
# 3  {'arco-geo-series': <Asset href=https://s3.waw...
# 4  {'arco-time-series': <Asset href=https://s3.wa...

# %% [markdown]
# ### Select a Collection and Fetch Items
# Choose a collection and list the available items (datasets), filtered by date range and geographic region.

# %%
def filter_items_by_time(items_df, start_date, end_date):
    """
    Filter items based on the time range.
    """
    items_df['item_starttime'] = pd.to_datetime(items_df['item_starttime'])
    items_df['item_endtime'] = pd.to_datetime(items_df['item_endtime'])
    items_df = items_df.sort_values(by='item_starttime')
    return items_df[(items_df['item_starttime'] > start_date) & (items_df['item_endtime'] < end_date)]

# Define time range
start_date = '2000-01-01'
end_date = '2030-12-31'

time_df = filter_items_by_time(oxygen_habitat_temperature_items_df, start_date, end_date)
time_df.head()
# Out:
#                                          Collection ID  \
# 738             climate_forecast-sea_water_temperature
# 739             climate_forecast-sea_water_temperature
# 294  climate_forecast-sea_surface_foundation_temper...
# 148  climate_forecast-mole_concentration_of_dissolv...
# 147  climate_forecast-mole_concentration_of_dissolv...
#
#                                   Item ID  \
# 738  20c3b69e-e60d-540f-9319-33e5f0c1b5b9
# 739  a45cc962-398e-52fa-8d57-e36df1882cb3
# 294  85c55083-3d82-5abe-899c-2be915fd8c99
# 148  e3e48210-8e39-5a33-ac19-9ee69d4f91fd
# 147  7bec1fdc-3863-59e2-aec1-98d74001619d
#
#                                            Item bounds  \
# 738  {'type': 'Polygon', 'coordinates': [[[-179.999...
# 739  {'type': 'Polygon', 'coordinates': [[[-179.999...
# 294  {'type': 'Polygon', 'coordinates': [[[-179.975...
# 148  {'type': 'Polygon', 'coordinates': [[[-180, 43...
# 147  {'type': 'Polygon', 'coordinates': [[[-180, 43...
#
#                item_starttime              item_endtime  \
# 738 2001-01-04 16:47:52+00:00 2023-12-31 23:59:00+00:00
# 739 2001-01-04 16:47:52+00:00 2023-12-31 23:59:00+00:00
# 294 2007-01-01 00:00:00+00:00 2025-01-09 00:00:00+00:00
# 148 2007-01-01 00:00:00+00:00 2022-12-31 00:00:00+00:00
# 147 2007-01-01 00:00:00+00:00 2022-12-31 00:00:00+00:00
#
#                                                 Assets
# 738  {'arco-time-series': <Asset href=https://s3.wa...
# 739  {'arco-geo-series': <Asset href=https://s3.waw...
# 294  {'arco-geo-series': <Asset href=https://s3.waw...
# 148  {'arco-geo-series': <Asset href=https://s3.waw...
# 147  {'arco-time-series': <Asset href=https://s3.wa...

# %% [markdown]
# ### Look for Cloud-Optimized Assets
# From each item, find and extract cloud-optimized assets (like Zarr or Parquet) that can be processed further.

# %%
all_items_assets = []
           # Now filter the assets
all_items_assets = []
for _, row in time_df.iterrows():
    collection_id = row['Collection ID']
    item_id = row['Item ID']
    bounds = row['Item bounds']
    data_starttime = row['item_starttime']
    data_endtime = row['item_endtime']
    assets = row['Assets']
    
    for asset_key, asset in assets.items():
        if asset.href.endswith('.zarr') or asset.href.endswith('.zarr/') or asset.href.endswith('.parquet'):
            # Append asset information to the list
            all_items_assets.append({'Collection ID': collection_id, 'Item ID': item_id, 'Data Start': data_starttime, 'Data End': data_endtime, 'Bounds': bounds, 'Asset Key': asset_key, 'Asset Href': asset.href})

# Create a DataFrame for assets
assets_df = pd.DataFrame(all_items_assets)
assets_df.head()

assets_df.to_csv('temperature_oxygen_habitat_arco_assets.csv')
