# %% [markdown]
# # Retrieve a Eurobis dataset
# Imagine you are interested in occurrence data, for instance this zooplankton dataset on [Eurobis](https://www.eurobis.org/imis?module=dataset&dasid=4687). You can also find this dataset via these portals:
# - [IPT](https://www.vliz.be/nl/imis?module=dataset&dasid=4685&printversion=1&dropIMIStitle=1)
# - [EMODnet](https://emodnet.ec.europa.eu/geonetwork/srv/eng/catalog.search#/metadata/6d617269-6e65-696e-666f-000000004687)
# - [LifeWatch](https://rshiny.lifewatch.be/flowcam-data/)
#
# This tutorial will illustrate how to get to this data via the DTO.
# ## 0. Setup environment
# #### Requirements

# %%
packages = ["contextily",
            "pandas",
            "geopandas",
            "matplotlib",
            "pyarrow",
            "pystac_client"]

# %% [markdown]
# #### Install packages

# %%
for package in packages:
    # %pip install {package}
# Out:
# Requirement already satisfied: contextily in /opt/python/lib/python3.13/site-packages (1.6.2)
# Requirement already satisfied: geopy in /opt/python/lib/python3.13/site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (from contextily) (3.10.7)
# Requirement already satisfied: mercantile in /opt/python/lib/python3.13/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /opt/python/lib/python3.13/site-packages (from contextily) (12.0.0)
# Requirement already satisfied: rasterio in /opt/python/lib/python3.13/site-packages (from contextily) (1.4.3)
# Requirement already satisfied: requests in /opt/python/lib/python3.13/site-packages (from contextily) (2.32.5)
# Requirement already satisfied: joblib in /opt/python/lib/python3.13/site-packages (from contextily) (1.5.2)
# Requirement already satisfied: xyzservices in /opt/python/lib/python3.13/site-packages (from contextily) (2025.10.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/python/lib/python3.13/site-packages (from geopy->contextily) (2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (25.0)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Requirement already satisfied: click>=3.0 in /opt/python/lib/python3.13/site-packages (from mercantile->contextily) (8.3.0)
# Requirement already satisfied: affine in /opt/python/lib/python3.13/site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /opt/python/lib/python3.13/site-packages (from rasterio->contextily) (25.4.0)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from rasterio->contextily) (2025.10.5)
# Requirement already satisfied: cligj>=0.5 in /opt/python/lib/python3.13/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/python/lib/python3.13/site-packages (from rasterio->contextily) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests->contextily) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests->contextily) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests->contextily) (2.5.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/python/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/python/lib/python3.13/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopandas in /opt/python/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /opt/python/lib/python3.13/site-packages (from geopandas) (2.3.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/python/lib/python3.13/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /opt/python/lib/python3.13/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/python/lib/python3.13/site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/python/lib/python3.13/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /opt/python/lib/python3.13/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/python/lib/python3.13/site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in /opt/python/lib/python3.13/site-packages (21.0.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pystac_client in /opt/python/lib/python3.13/site-packages (0.9.0)
# Requirement already satisfied: requests>=2.28.2 in /opt/python/lib/python3.13/site-packages (from pystac_client) (2.32.5)
# Requirement already satisfied: pystac>=1.10.0 in /opt/python/lib/python3.13/site-packages (from pystac[validation]>=1.10.0->pystac_client) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pystac_client) (2.9.0.post0)
# Requirement already satisfied: jsonschema~=4.18 in /opt/python/lib/python3.13/site-packages (from pystac[validation]>=1.10.0->pystac_client) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/python/lib/python3.13/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/python/lib/python3.13/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/python/lib/python3.13/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/python/lib/python3.13/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.27.1)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pystac_client) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests>=2.28.2->pystac_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests>=2.28.2->pystac_client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests>=2.28.2->pystac_client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/lib/python3.13/site-packages (from requests>=2.28.2->pystac_client) (2025.10.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Load packages

# %%
import pyarrow.parquet as pq
import pyarrow.fs
import pyarrow.dataset as ds
import pyarrow.compute as pc
import pyarrow.fs
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import Point
import pystac_client

# %% [markdown]
# ## 1. Find the occurrence dataset
# On 2025-03-07 this is the current occurrence dataset:
# - s3.waw3-1.cloudferro.com/emodnet/biology/eurobis_occurrence_data/eurobis_occurrences_geoparquet_2024-10-01.parquet
# <br><br>
# The dataset is sometimes updated & URL changed, so it is best to search the STAC to make sure we have the latest version.
# <br><br>
# We use pystac_client to query the STAC, raed the docs [here](https://pystac-client.readthedocs.io/en/stable/index.html).
# #### 1.1 Connect to STAC catalag

# %%
url = 'https://catalog.dive.edito.eu'
client = pystac_client.Client.open(url)
print(client)
# Out:
# <Client id=root>

# %% [markdown]
# Explore the different collections

# %%
collections = list(client.get_collections())
print(len(collections))
# Out:
# 442

# %% [markdown]
# #### 1.2 Search collections with occurrence data

# %%
variable = "emodnet-occurrence_data"

items = []
for collection in collections:
    if variable in collection.id:
        print(collection.id)
        for i, item in enumerate(collection.get_items()):
            items.append(item)
            
print(items)
# Out:
# emodnet-occurrence_data
# [<Item id=426b87c6-409d-5dfd-9522-1be4e30b4b01>]

# %% [markdown]
# This results in one dataset that contains occurrence data.
# #### 1.3 Find the data URL
# Each item has assets, we want to find the parquet asset and extract that one.

# %%
for item in items:
    for key, value in item.assets.items():
        print(f"{key}: {value}")
        print("-"*25)
        if key == "parquet":
            occurrence_data = value.href
# Out:
# xml: <Asset href=https://emodnet.ec.europa.eu/geonetwork/srv/api/records/6d617269-6e65-696e-666f-000000001510/formatters/xml>
# -------------------------
# csw: <Asset href=https://emodnet.ec.europa.eu/geonetwork/emodnet/eng/csw?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=6d617269-6e65-696e-666f-000000001510>
# -------------------------
# wms: <Asset href=https://geo.vliz.be/geoserver/wms?SERVICE=WMS&REQUEST=GetMap&LAYERS=Dataportal:eurobis_rasters-obisenv&VERSION=1.1.1&CRS=CRS:84&BBOX=-180,-90,180,90&WIDTH=800&HEIGHT=600&FORMAT=image/png>
# -------------------------
# parquet: <Asset href=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_biology/12639/marine_biodiversity_observations_2025-09-22.parquet>
# -------------------------
# parquet-datalab-data-explorer: <Asset href=https://datalab.dive.edito.eu/data-explorer?source=https://s3.waw3-1.cloudferro.com/emodnet/emodnet_biology/12639/marine_biodiversity_observations_2025-09-22.parquet>
# -------------------------

# %%
print(occurrence_data)
# Out:
# https://s3.waw3-1.cloudferro.com/emodnet/emodnet_biology/12639/marine_biodiversity_observations_2025-09-22.parquet

# %% [markdown]
# ## 2. Open the occurrences dataset
# #### connect to the S3 object storage
# To connect to the dataset, you need following information:
#
# - Host: base url
# - Bucket: first part of the path after host
# - Key: all other path specifications
#
# This information is all in the URI. It can be extracted manualy or automated.
# #### Manual resource specification

# %%
host = "s3.waw3-1.cloudferro.com"
bucket_name = "emodnet"
key = "biology/eurobis_occurrence_data/eurobis_occurrences_geoparquet_2024-10-01.parquet"

# %% [markdown]
# #### Automated resource specification

# %%
from urllib.parse import urlparse
parsed_url = urlparse(occurrence_data)
host = parsed_url.hostname
bucket_name = parsed_url.path.split('/')[1]
key = '/'.join(parsed_url.path.split('/')[2:])

# %%
print("host =", host)
print("bucket_name =", bucket_name)
print("key =", key)
# Out:
# host = s3.waw3-1.cloudferro.com
# bucket_name = emodnet
# key = emodnet_biology/12639/marine_biodiversity_observations_2025-09-22.parquet

# %%
s3 = pyarrow.fs.S3FileSystem(endpoint_override=host, anonymous=True)
s3_path = f"{bucket_name}/{key}"

# %% [markdown]
# #### Open file and inspect the schema
# Open the dataset. Notice this is not equal to loading the data. The entire dataset contains way to many records to load at once, we will filter en load in a later step.

# %%
dataset = ds.dataset(s3_path, filesystem=s3, format="parquet")
print(dataset.schema)
# Out:
# id: int64
# datelastmodified: timestamp[us, tz=UTC]
# datasetid: int32
# institutioncode: string
# collectioncode: string
# eventid: string
# observationdate: timestamp[us, tz=UTC]
# season: string
# yearcollected: int16
# startyearcollected: int16
# endyearcollected: int16
# monthcollected: int16
# startmonthcollected: int16
# endmonthcollected: int16
# daycollected: int16
# startdaycollected: int16
# enddaycollected: int16
# timeofday: double
# starttimeofday: double
# endtimeofday: double
# timezone: string
# continentocean: string
# country: string
# stateprovince: string
# county: string
# collectornumber: string
# fieldnumber: string
# longitude: double
# startlongitude: double
# endlongitude: double
# latitude: double
# startlatitude: double
# endlatitude: double
# coordinateprecision: double
# verbatimpositiondetail: string
# minimumdepth: double
# maximumdepth: double
# occurrenceid: string
# scientificname: string
# aphiaid: int32
# taxonrank: int16
# rankname: string
# scientificname_accepted: string
# scientificnameauthor: string
# aphiaidaccepted: int32
# kingdom: string
# phylum: string
# class: string
# order: string
# family: string
# genus: string
# subgenus: string
# species: string
# subspecies: string
# occurrenceremarks: string
# basisofrecord: string
# typestatus: string
# catalognumber: string
# recordurl: string
# collector: string
# identifiedby: string
# yearidentified: int16
# monthidentified: int16
# dayidentified: int16
# preparationtype: string
# samplingeffort: string
# samplingprotocol: string
# the_geom: binary
# eurobis_unique_positions_id: int32
# julianday: string
# startjulianday: int16
# endjulianday: int16
# coordinateprecision_category: int32
# start_endcoordinateprecision: double
# boundingbox: string
# minimumelevation: double
# maximumelevation: double
# depthrange: string
# temperature: double
# individualcount: double
# observedweight: double
# previouscatalognumber: string
# relationshiptype: string
# relatedcatalogitem: string
# samplesize: string
# qc: int32
# datageneralizations: string
# eventremarks: string
# locationremarks: string
# associatedsequences: string
# associatedmedia: string
# organismid: string
# geodeticdatum: string
# dynamicproperties: string
# identificationverificationstatus: string
# identificationreferences: string
# organismquantity: string
# organismquantitytype: string
# samplesizevalue: double
# samplesizeunit: string
# materialsampleid: string
# taxonconceptid: string
# seasonid: int16
# dataprovider_id: int32
# parameter: string
# parameter_value: string
# parameter_group_id: int32
# parameter_measurementtypeid: string
# parameter_bodcterm: string
# parameter_bodcterm_definition: string
# parameter_standardunit: string
# parameter_standardunitid: string
# parameter_imisdasid: int32
# parameter_ipturl: string
# parameter_original_measurement_type: string
# parameter_original_measurement_unit: string
# parameter_conversion_factor_to_standard_unit: string
# parameter_measurementid: string
# event_id: string
# eventtype: string
# eventtype_id: int32
# occurrenceid_unique: int32
# geoobjectsids: list<element: int32>
#   child 0, element: int32
# geoid: list<element: int32>
#   child 0, element: int32
# datetime: timestamp[us, tz=UTC]
# time_precision: int16
# measurement_type_group_ids: list<element: int32>
#   child 0, element: int32
# dnaderived: string
# verbatimidentification: string
# higherclassification: string
# taxonid: string

# %% [markdown]
# ## 2. Filter the data
# We will filter for copepods (apiaID 1080 near the Flemish coast (latitude 51-51.5; longitude 2.5-3.3).

# %%
columns_needed = ["aphiaid", "latitude", "longitude"]
filtered_table = dataset.to_table(
    columns=columns_needed,
    filter=(
        (pc.field("aphiaid") == 1080) &
        (pc.field("latitude") >= 51) &
        (pc.field("latitude") <= 51.5) &
        (pc.field("longitude") >= 2.5) &
        (pc.field("longitude") <= 3.3)
    )
)

# %% [markdown]
# #### Convert to Pandas DataFrame

# %%
df = filtered_table.to_pandas()

# %% [markdown]
# See how many records in this dataframe

# %%
print(f"{len(df)=}")

# %% [markdown]
# Print some records to see the data.

# %%
for line in df.head(10).itertuples():
    print(line)

# %% [markdown]
# ## 3.Plotting the data
# Lets visualize the data for better understanding.

# %%
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df.longitude, df.latitude),
    crs="EPSG:4326"  # WGS84 coordinate system
)
fig, ax = plt.subplots(figsize=(10, 10))
gdf = gdf.to_crs(epsg=3857)  # Reproject to Web Mercator for compatibility with contextily
gdf.plot(ax=ax, color="blue", markersize=10, alpha=0.6, label="Occurrences")
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, zoom=10)
ax.set_title("Map of Filtered AphiaID Occurrences with Background Map")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Conclusion
# This notebook demonstrated how to reach the Eurobis data via EDITO data lake. All occurence datasets are merged in a single parquet file in the data lake.
